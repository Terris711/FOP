# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('shrimp_pop10-30.csv')

print(df)

df.plot()

plt.title("Shrimp Breeding")
plt.show()
# Out:
#     Initial Population  Final Population
# 0                   10                10
# 1                   12                12
# 2                   14                29
# 3                   16                31
# 4                   18                33
# 5                   20                35
# 6                   22                37
# 7                   24                39
# 8                   26                56
# 9                   28                58
# 10                  30                60
